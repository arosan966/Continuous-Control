# %% [markdown]
# # Continuous Control
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
env = UnityEnvironment(file_name='/home/deep-reinforcement-learning/p2_continuous-control/Reacher_Linux_NoVis/Reacher.x86_64')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_size -> 5.0
# 		goal_speed -> 1.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# The simulation contains `20` identical agents, each with its own copy of the environment.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 20
# Size of each action: 4
# There are 20 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.75471878e+00 -1.00000000e+00
#   5.55726624e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
while True:
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))
# Out:
# Total score (averaged over agents) this episode: 0.21249999525025487

# %% [markdown]
# When finished, you can close the environment.

# %%
import gym
import random
import torch
import time
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from ddpg_agent import Agent
agent = Agent(state_size=state_size, action_size=action_size, random_seed=0)

def ddpg(n_episodes=2000, steps=1000):    
    scores_deque = deque(maxlen=100)
    scores = []
    i_episode = 0
    while True:    
        start = time.time()
        i_episode += 1
        average_score = 0
        agent.time_step = 0   
        env_info = env.reset(train_mode=True)[brain_name]      # reset the environment    
        states = env_info.vector_observations                  # get the current state (for each agent)
        score = np.zeros(num_agents)                          # initialize the score (for each agent)        
        agent.reset()
        for i_step in range(steps):
            agent.time_step += 1
            actions = agent.act(states)
            actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
            env_info = env.step(actions)[brain_name]           # send all actions to tne environment
            next_states = env_info.vector_observations         # get next state (for each agent)
            rewards = env_info.rewards                         # get reward (for each agent)
            dones = env_info.local_done                        # see if episode finished
            agent.step(states, actions, rewards, next_states, dones)
            states = next_states
            score += rewards
            if all(dones):
                break
        
        scores.append(np.mean(score))
        scores_deque.append(np.mean(score))
        average_score = np.mean(scores_deque)
                
        print("Episode: ", i_episode)
        print("Min Score: {:.2f}  Max Score: {:.2f}".format(score.min(), score.max()))
        print("AvgScore: {:.2f}".format(average_score))
        print("Time: {:.2f} seconds\n".format(time.time() - start))

        if average_score > 30:
            torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')            
            break
    return scores

scores = ddpg()
# Out:
# Episode:  1
# Min Score: 0.00  Max Score: 0.06
# AvgScore: 0.00
# Time: 35.33 seconds
#
# Episode:  2
# Min Score: 0.00  Max Score: 0.00
# AvgScore: 0.00
# Time: 35.86 seconds
#
# Episode:  3
# Min Score: 0.00  Max Score: 0.72
# AvgScore: 0.07
# Time: 37.02 seconds
#
# Episode:  4
# Min Score: 0.07  Max Score: 0.80
# AvgScore: 0.15
# Time: 38.27 seconds
#
# Episode:  5
# Min Score: 0.15  Max Score: 1.69
# AvgScore: 0.22
# Time: 38.43 seconds
#
# Episode:  6
# Min Score: 0.13  Max Score: 1.37
# AvgScore: 0.30
# Time: 41.41 seconds
#
# Episode:  7
# Min Score: 0.00  Max Score: 1.27
# AvgScore: 0.34
# Time: 39.10 seconds
#
# Episode:  8
# Min Score: 0.00  Max Score: 1.58
# AvgScore: 0.37
# Time: 37.49 seconds
#
# Episode:  9
# Min Score: 0.18  Max Score: 2.00
# AvgScore: 0.44
# Time: 38.33 seconds
#
# Episode:  10
# Min Score: 0.28  Max Score: 1.53
# AvgScore: 0.47
# Time: 37.09 seconds
#
# Episode:  11
# Min Score: 0.15  Max Score: 1.93
# AvgScore: 0.50
# Time: 40.14 seconds
#
# Episode:  12
# Min Score: 0.40  Max Score: 2.03
# AvgScore: 0.53
# Time: 39.37 seconds
#
# Episode:  13
# Min Score: 0.20  Max Score: 1.92
# AvgScore: 0.57
# Time: 37.85 seconds
#
# Episode:  14
# Min Score: 0.22  Max Score: 3.32
# AvgScore: 0.61
# Time: 38.47 seconds
#
# Episode:  15
# Min Score: 0.57  Max Score: 2.36
# AvgScore: 0.66
# Time: 39.74 seconds
#
# Episode:  16
# Min Score: 0.18  Max Score: 2.16
# AvgScore: 0.68
# Time: 40.35 seconds
#
# Episode:  17
# Min Score: 0.32  Max Score: 2.71
# AvgScore: 0.72
# Time: 40.58 seconds
#
# Episode:  18
# Min Score: 0.56  Max Score: 3.51
# AvgScore: 0.77
# Time: 39.78 seconds
#
# Episode:  19
# Min Score: 0.69  Max Score: 3.34
# AvgScore: 0.82
# Time: 42.19 seconds
#
# Episode:  20
# Min Score: 0.33  Max Score: 4.81
# AvgScore: 0.87
# Time: 41.21 seconds
#
# Episode:  21
# Min Score: 0.64  Max Score: 3.55
# AvgScore: 0.91
# Time: 43.58 seconds
#
# Episode:  22
# Min Score: 0.62  Max Score: 5.00
# AvgScore: 0.97
# Time: 42.85 seconds
#
# Episode:  23
# Min Score: 0.41  Max Score: 3.97
# AvgScore: 1.00
# Time: 45.48 seconds
#
# Episode:  24
# Min Score: 0.42  Max Score: 3.15
# AvgScore: 1.02
# Time: 41.10 seconds
#
# Episode:  25
# Min Score: 0.73  Max Score: 3.89
# AvgScore: 1.07
# Time: 40.58 seconds
#
# Episode:  26
# Min Score: 0.75  Max Score: 7.53
# AvgScore: 1.15
# Time: 42.02 seconds
#
# Episode:  27
# Min Score: 1.57  Max Score: 10.21
# AvgScore: 1.26
# Time: 41.24 seconds
#
# Episode:  28
# Min Score: 1.23  Max Score: 6.75
# AvgScore: 1.34
# Time: 41.47 seconds
#
# Episode:  29
# Min Score: 0.89  Max Score: 8.14
# AvgScore: 1.42
# Time: 42.19 seconds
#
# Episode:  30
# Min Score: 0.57  Max Score: 20.21
# AvgScore: 1.56
# Time: 41.02 seconds
#
# Episode:  31
# Min Score: 0.24  Max Score: 12.39
# AvgScore: 1.65
# Time: 41.75 seconds
#
# Episode:  32
# Min Score: 2.12  Max Score: 11.79
# AvgScore: 1.77
# Time: 41.10 seconds
#
# Episode:  33
# Min Score: 1.84  Max Score: 19.87
# AvgScore: 1.89
# Time: 40.23 seconds
#
# Episode:  34
# Min Score: 2.14  Max Score: 15.53
# AvgScore: 2.00
# Time: 41.03 seconds
#
# Episode:  35
# Min Score: 1.70  Max Score: 10.65
# AvgScore: 2.09
# Time: 40.74 seconds
#
# Episode:  36
# Min Score: 2.30  Max Score: 9.48
# AvgScore: 2.18
# Time: 41.72 seconds
#
# Episode:  37
# Min Score: 2.37  Max Score: 9.08
# AvgScore: 2.26
# Time: 40.38 seconds
#
# Episode:  38
# Min Score: 2.14  Max Score: 8.88
# AvgScore: 2.32
# Time: 42.04 seconds
#
# Episode:  39
# Min Score: 2.98  Max Score: 8.66
# AvgScore: 2.41
# Time: 41.85 seconds
#
# Episode:  40
# Min Score: 3.28  Max Score: 18.68
# AvgScore: 2.52
# Time: 40.65 seconds
#
# Episode:  41
# Min Score: 0.65  Max Score: 12.15
# AvgScore: 2.62
# Time: 42.02 seconds
#
# Episode:  42
# Min Score: 2.00  Max Score: 21.05
# AvgScore: 2.73
# Time: 41.52 seconds
#
# Episode:  43
# Min Score: 3.38  Max Score: 14.29
# AvgScore: 2.82
# Time: 41.10 seconds
#
# Episode:  44
# Min Score: 3.07  Max Score: 21.40
# AvgScore: 2.94
# Time: 41.76 seconds
#
# Episode:  45
# Min Score: 2.82  Max Score: 10.14
# AvgScore: 3.01
# Time: 41.50 seconds
#
# Episode:  46
# Min Score: 0.82  Max Score: 10.56
# AvgScore: 3.09
# Time: 41.43 seconds
#
# Episode:  47
# Min Score: 1.42  Max Score: 11.86
# AvgScore: 3.15
# Time: 41.67 seconds
#
# Episode:  48
# Min Score: 1.12  Max Score: 12.12
# AvgScore: 3.21
# Time: 40.80 seconds
#
# Episode:  49
# Min Score: 4.12  Max Score: 13.96
# AvgScore: 3.29
# Time: 41.78 seconds
#
# Episode:  50
# Min Score: 2.25  Max Score: 11.84
# AvgScore: 3.35
# Time: 40.63 seconds
#
# Episode:  51
# Min Score: 4.52  Max Score: 12.07
# AvgScore: 3.44
# Time: 41.50 seconds
#
# Episode:  52
# Min Score: 2.61  Max Score: 11.07
# AvgScore: 3.49
# Time: 41.94 seconds
#
# Episode:  53
# Min Score: 0.84  Max Score: 32.96
# AvgScore: 3.56
# Time: 40.49 seconds
#
# Episode:  54
# Min Score: 2.17  Max Score: 12.05
# AvgScore: 3.60
# Time: 41.74 seconds
#
# Episode:  55
# Min Score: 0.95  Max Score: 11.09
# AvgScore: 3.66
# Time: 41.24 seconds
#
# Episode:  56
# Min Score: 4.22  Max Score: 11.62
# AvgScore: 3.73
# Time: 40.53 seconds
#
# Episode:  57
# Min Score: 4.28  Max Score: 11.24
# AvgScore: 3.80
# Time: 42.32 seconds
#
# Episode:  58
# Min Score: 1.77  Max Score: 11.50
# AvgScore: 3.87
# Time: 40.95 seconds
#
# Episode:  59
# Min Score: 2.81  Max Score: 11.53
# AvgScore: 3.94
# Time: 41.76 seconds
#
# Episode:  60
# Min Score: 2.97  Max Score: 25.65
# AvgScore: 4.04
# Time: 41.99 seconds
#
# Episode:  61
# Min Score: 2.89  Max Score: 12.24
# AvgScore: 4.12
# Time: 41.54 seconds
#
# Episode:  62
# Min Score: 0.98  Max Score: 25.57
# AvgScore: 4.22
# Time: 41.83 seconds
#
# Episode:  63
# Min Score: 6.87  Max Score: 15.05
# AvgScore: 4.31
# Time: 41.34 seconds
#
# Episode:  64
# Min Score: 2.66  Max Score: 14.06
# AvgScore: 4.40
# Time: 41.05 seconds
#
# Episode:  65
# Min Score: 6.69  Max Score: 12.56
# AvgScore: 4.49
# Time: 41.24 seconds
#
# Episode:  66
# Min Score: 6.41  Max Score: 16.50
# AvgScore: 4.59
# Time: 41.22 seconds
#
# Episode:  67
# Min Score: 6.72  Max Score: 13.50
# AvgScore: 4.68
# Time: 41.80 seconds
#
# Episode:  68
# Min Score: 1.08  Max Score: 13.70
# AvgScore: 4.76
# Time: 41.15 seconds
#
# Episode:  69
# Min Score: 6.51  Max Score: 18.28
# AvgScore: 4.86
# Time: 41.35 seconds
#
# Episode:  70
# Min Score: 1.38  Max Score: 20.70
# AvgScore: 4.97
# Time: 41.60 seconds
#
# Episode:  71
# Min Score: 9.64  Max Score: 19.30
# AvgScore: 5.09
# Time: 40.87 seconds
#
# Episode:  72
# Min Score: 6.10  Max Score: 19.41
# AvgScore: 5.20
# Time: 41.67 seconds
#
# Episode:  73
# Min Score: 7.70  Max Score: 16.96
# AvgScore: 5.31
# Time: 41.07 seconds
#
# Episode:  74
# Min Score: 5.57  Max Score: 17.56
# AvgScore: 5.39
# Time: 41.86 seconds
#
# Episode:  75
# Min Score: 8.01  Max Score: 19.20
# AvgScore: 5.50
# Time: 41.73 seconds
#
# Episode:  76
# Min Score: 1.21  Max Score: 24.52
# AvgScore: 5.58
# Time: 40.71 seconds
#
# Episode:  77
# Min Score: 6.28  Max Score: 27.18
# AvgScore: 5.67
# Time: 41.08 seconds
#
# Episode:  78
# Min Score: 7.66  Max Score: 20.08
# AvgScore: 5.76
# Time: 41.61 seconds
#
# Episode:  79
# Min Score: 6.54  Max Score: 18.15
# AvgScore: 5.85
# Time: 40.48 seconds
#
# Episode:  80
# Min Score: 1.60  Max Score: 23.89
# AvgScore: 5.93
# Time: 41.86 seconds
#
# Episode:  81
# Min Score: 7.70  Max Score: 21.42
# AvgScore: 6.04
# Time: 41.63 seconds
#
# Episode:  82
# Min Score: 6.13  Max Score: 20.46
# AvgScore: 6.14
# Time: 40.59 seconds
#
# Episode:  83
# Min Score: 9.24  Max Score: 23.61
# AvgScore: 6.24
# Time: 42.16 seconds
#
# Episode:  84
# Min Score: 1.65  Max Score: 22.11
# AvgScore: 6.33
# Time: 40.94 seconds
#
# Episode:  85
# Min Score: 9.69  Max Score: 20.47
# AvgScore: 6.44
# Time: 41.40 seconds
#
# Episode:  86
# Min Score: 7.92  Max Score: 23.58
# AvgScore: 6.54
# Time: 40.88 seconds
#
# Episode:  87
# Min Score: 12.93  Max Score: 24.50
# AvgScore: 6.67
# Time: 41.94 seconds
#
# Episode:  88
# Min Score: 12.07  Max Score: 21.19
# AvgScore: 6.78
# Time: 41.30 seconds
#
# Episode:  89
# Min Score: 10.16  Max Score: 27.99
# AvgScore: 6.92
# Time: 41.02 seconds
#
# Episode:  90
# Min Score: 11.87  Max Score: 23.24
# AvgScore: 7.03
# Time: 41.78 seconds
#
# Episode:  91
# Min Score: 11.87  Max Score: 22.15
# AvgScore: 7.15
# Time: 41.07 seconds
#
# Episode:  92
# Min Score: 1.46  Max Score: 27.18
# AvgScore: 7.27
# Time: 40.99 seconds
#
# Episode:  93
# Min Score: 12.37  Max Score: 25.50
# AvgScore: 7.39
# Time: 41.99 seconds
#
# Episode:  94
# Min Score: 13.43  Max Score: 24.47
# AvgScore: 7.52
# Time: 40.49 seconds
#
# Episode:  95
# Min Score: 13.03  Max Score: 32.77
# AvgScore: 7.64
# Time: 41.39 seconds
#
# Episode:  96
# Min Score: 13.16  Max Score: 24.51
# AvgScore: 7.75
# Time: 41.09 seconds
#
# Episode:  97
# Min Score: 15.37  Max Score: 25.02
# AvgScore: 7.88
# Time: 41.23 seconds
#
# Episode:  98
# Min Score: 11.03  Max Score: 25.51
# AvgScore: 7.98
# Time: 42.01 seconds
#
# Episode:  99
# Min Score: 2.38  Max Score: 25.64
# AvgScore: 8.08
# Time: 40.89 seconds
#
# Episode:  100
# Min Score: 13.73  Max Score: 31.44
# AvgScore: 8.19
# Time: 41.16 seconds
#
# Episode:  101
# Min Score: 16.88  Max Score: 36.22
# AvgScore: 8.40
# Time: 41.28 seconds
#
# Episode:  102
# Min Score: 14.35  Max Score: 34.71
# AvgScore: 8.61
# Time: 40.34 seconds
#
# Episode:  103
# Min Score: 16.18  Max Score: 24.42
# AvgScore: 8.81
# Time: 42.96 seconds
#
# Episode:  104
# Min Score: 18.26  Max Score: 28.28
# AvgScore: 9.02
# Time: 44.85 seconds
#
# Episode:  105
# Min Score: 14.95  Max Score: 26.60
# AvgScore: 9.23
# Time: 47.81 seconds
#
# Episode:  106
# Min Score: 11.02  Max Score: 27.67
# AvgScore: 9.41
# Time: 44.15 seconds
#
# Episode:  107
# Min Score: 11.74  Max Score: 28.29
# AvgScore: 9.61
# Time: 43.63 seconds
#
# Episode:  108
# Min Score: 10.90  Max Score: 22.68
# AvgScore: 9.78
# Time: 42.14 seconds
#
# Episode:  109
# Min Score: 16.89  Max Score: 31.15
# AvgScore: 10.01
# Time: 43.05 seconds
#
# Episode:  110
# Min Score: 9.07  Max Score: 26.61
# AvgScore: 10.19
# Time: 41.01 seconds
#
# Episode:  111
# Min Score: 8.74  Max Score: 30.38
# AvgScore: 10.38
# Time: 45.21 seconds
#
# Episode:  112
# Min Score: 15.46  Max Score: 30.80
# AvgScore: 10.59
# Time: 43.65 seconds
#
# Episode:  113
# Min Score: 13.41  Max Score: 30.01
# AvgScore: 10.81
# Time: 49.82 seconds
#
# Episode:  114
# Min Score: 11.85  Max Score: 29.29
# AvgScore: 11.01
# Time: 44.04 seconds
#
# Episode:  115
# Min Score: 9.45  Max Score: 32.76
# AvgScore: 11.22
# Time: 44.68 seconds
#
# Episode:  116
# Min Score: 12.09  Max Score: 26.47
# AvgScore: 11.40
# Time: 43.37 seconds
#
# Episode:  117
# Min Score: 13.44  Max Score: 31.73
# AvgScore: 11.64
# Time: 41.87 seconds
#
# Episode:  118
# Min Score: 6.46  Max Score: 36.58
# AvgScore: 11.83
# Time: 42.42 seconds
#
# Episode:  119
# Min Score: 15.96  Max Score: 31.36
# AvgScore: 12.04
# Time: 41.66 seconds
#
# Episode:  120
# Min Score: 13.93  Max Score: 33.93
# AvgScore: 12.26
# Time: 42.56 seconds
#
# Episode:  121
# Min Score: 10.80  Max Score: 30.37
# AvgScore: 12.46
# Time: 41.56 seconds
#
# Episode:  122
# Min Score: 12.85  Max Score: 32.72
# AvgScore: 12.67
# Time: 41.53 seconds
#
# Episode:  123
# Min Score: 10.81  Max Score: 39.98
# AvgScore: 12.92
# Time: 43.08 seconds
#
# Episode:  124
# Min Score: 10.03  Max Score: 34.37
# AvgScore: 13.11
# Time: 41.80 seconds
#
# Episode:  125
# Min Score: 8.77  Max Score: 31.27
# AvgScore: 13.30
# Time: 40.85 seconds
#
# Episode:  126
# Min Score: 16.65  Max Score: 32.17
# AvgScore: 13.51
# Time: 41.95 seconds
#
# Episode:  127
# Min Score: 10.58  Max Score: 28.70
# AvgScore: 13.69
# Time: 41.15 seconds
#
# Episode:  128
# Min Score: 13.20  Max Score: 30.49
# AvgScore: 13.87
# Time: 41.86 seconds
#
# Episode:  129
# Min Score: 16.78  Max Score: 32.29
# AvgScore: 14.09
# Time: 41.70 seconds
#
# Episode:  130
# Min Score: 17.11  Max Score: 38.37
# AvgScore: 14.28
# Time: 41.39 seconds
#
# Episode:  131
# Min Score: 17.13  Max Score: 31.28
# AvgScore: 14.48
# Time: 42.29 seconds
#
# Episode:  132
# Min Score: 14.98  Max Score: 29.63
# AvgScore: 14.67
# Time: 41.38 seconds
#
# Episode:  133
# Min Score: 16.07  Max Score: 30.26
# AvgScore: 14.86
# Time: 41.67 seconds
#
# Episode:  134
# Min Score: 17.60  Max Score: 30.89
# AvgScore: 15.04
# Time: 43.10 seconds
#
# Episode:  135
# Min Score: 12.83  Max Score: 31.03
# AvgScore: 15.24
# Time: 41.23 seconds
#
# Episode:  136
# Min Score: 21.64  Max Score: 34.02
# AvgScore: 15.48
# Time: 41.17 seconds
#
# Episode:  137
# Min Score: 15.25  Max Score: 31.35
# AvgScore: 15.67
# Time: 41.77 seconds
#
# Episode:  138
# Min Score: 12.61  Max Score: 31.03
# AvgScore: 15.85
# Time: 40.70 seconds
#
# Episode:  139
# Min Score: 14.89  Max Score: 35.51
# AvgScore: 16.05
# Time: 41.27 seconds
#
# Episode:  140
# Min Score: 14.55  Max Score: 29.68
# AvgScore: 16.20
# Time: 41.46 seconds
#
# Episode:  141
# Min Score: 10.86  Max Score: 26.38
# AvgScore: 16.33
# Time: 41.96 seconds
#
# Episode:  142
# Min Score: 16.98  Max Score: 30.10
# AvgScore: 16.50
# Time: 42.32 seconds
#
# Episode:  143
# Min Score: 17.74  Max Score: 28.04
# AvgScore: 16.67
# Time: 42.27 seconds
#
# Episode:  144
# Min Score: 17.96  Max Score: 27.90
# AvgScore: 16.81
# Time: 41.49 seconds
#
# Episode:  145
# Min Score: 13.40  Max Score: 23.41
# AvgScore: 16.94
# Time: 47.27 seconds
#
# Episode:  146
# Min Score: 14.61  Max Score: 25.77
# AvgScore: 17.08
# Time: 42.85 seconds
#
# Episode:  147
# Min Score: 15.80  Max Score: 25.02
# AvgScore: 17.23
# Time: 44.17 seconds
#
# Episode:  148
# Min Score: 10.98  Max Score: 25.11
# AvgScore: 17.37
# Time: 42.80 seconds
#
# Episode:  149
# Min Score: 12.56  Max Score: 26.96
# AvgScore: 17.51
# Time: 42.24 seconds
#
# Episode:  150
# Min Score: 15.57  Max Score: 26.57
# AvgScore: 17.65
# Time: 41.85 seconds
#
# Episode:  151
# Min Score: 13.50  Max Score: 33.75
# AvgScore: 17.78
# Time: 43.35 seconds
#
# Episode:  152
# Min Score: 13.69  Max Score: 25.70
# AvgScore: 17.91
# Time: 43.20 seconds
#
# Episode:  153
# Min Score: 16.06  Max Score: 29.42
# AvgScore: 18.09
# Time: 42.07 seconds
#
# Episode:  154
# Min Score: 16.32  Max Score: 27.06
# AvgScore: 18.26
# Time: 41.60 seconds
#
# Episode:  155
# Min Score: 20.11  Max Score: 29.99
# AvgScore: 18.44
# Time: 42.76 seconds
#
# Episode:  156
# Min Score: 22.51  Max Score: 32.70
# AvgScore: 18.64
# Time: 41.54 seconds
#
# Episode:  157
# Min Score: 19.96  Max Score: 32.02
# AvgScore: 18.81
# Time: 42.19 seconds
#
# Episode:  158
# Min Score: 18.66  Max Score: 31.32
# AvgScore: 18.98
# Time: 42.26 seconds
#
# Episode:  159
# Min Score: 15.69  Max Score: 28.98
# AvgScore: 19.13
# Time: 41.32 seconds
#
# Episode:  160
# Min Score: 19.86  Max Score: 30.28
# AvgScore: 19.28
# Time: 43.22 seconds
#
# Episode:  161
# Min Score: 15.51  Max Score: 28.97
# AvgScore: 19.42
# Time: 43.57 seconds
#
# Episode:  162
# Min Score: 13.77  Max Score: 27.80
# AvgScore: 19.54
# Time: 45.42 seconds
#
# Episode:  163
# Min Score: 16.98  Max Score: 29.51
# AvgScore: 19.69
# Time: 45.71 seconds
#
# Episode:  164
# Min Score: 20.00  Max Score: 32.47
# AvgScore: 19.86
# Time: 41.51 seconds
#
# Episode:  165
# Min Score: 19.39  Max Score: 31.27
# AvgScore: 20.00
# Time: 42.50 seconds
#
# Episode:  166
# Min Score: 21.43  Max Score: 31.96
# AvgScore: 20.16
# Time: 43.43 seconds
#
# Episode:  167
# Min Score: 19.34  Max Score: 29.52
# AvgScore: 20.30
# Time: 41.84 seconds
#
# Episode:  168
# Min Score: 18.43  Max Score: 30.69
# AvgScore: 20.46
# Time: 42.41 seconds
#
# Episode:  169
# Min Score: 23.07  Max Score: 34.46
# AvgScore: 20.64
# Time: 41.83 seconds
#
# Episode:  170
# Min Score: 23.03  Max Score: 32.87
# AvgScore: 20.80
# Time: 42.40 seconds
#
# Episode:  171
# Min Score: 19.75  Max Score: 32.92
# AvgScore: 20.95
# Time: 43.30 seconds
#
# Episode:  172
# Min Score: 21.71  Max Score: 35.90
# AvgScore: 21.09
# Time: 42.09 seconds
#
# Episode:  173
# Min Score: 20.78  Max Score: 34.38
# AvgScore: 21.24
# Time: 42.73 seconds
#
# Episode:  174
# Min Score: 21.28  Max Score: 40.16
# AvgScore: 21.42
# Time: 42.44 seconds
#
# Episode:  175
# Min Score: 18.26  Max Score: 34.84
# AvgScore: 21.58
# Time: 42.26 seconds
#
# Episode:  176
# Min Score: 18.15  Max Score: 39.90
# AvgScore: 21.75
# Time: 43.52 seconds
#
# Episode:  177
# Min Score: 17.53  Max Score: 37.34
# AvgScore: 21.90
# Time: 41.86 seconds
#
# Episode:  178
# Min Score: 21.04  Max Score: 38.20
# AvgScore: 22.07
# Time: 41.55 seconds
#
# Episode:  179
# Min Score: 23.49  Max Score: 38.20
# AvgScore: 22.24
# Time: 41.95 seconds
#
# Episode:  180
# Min Score: 22.78  Max Score: 40.25
# AvgScore: 22.40
# Time: 41.62 seconds
#
# Episode:  181
# Min Score: 25.73  Max Score: 42.38
# AvgScore: 22.57
# Time: 42.15 seconds
#
# Episode:  182
# Min Score: 21.37  Max Score: 40.05
# AvgScore: 22.73
# Time: 41.12 seconds
#
# Episode:  183
# Min Score: 23.44  Max Score: 36.76
# AvgScore: 22.87
# Time: 41.99 seconds
#
# Episode:  184
# Min Score: 20.84  Max Score: 30.35
# AvgScore: 23.00
# Time: 41.55 seconds
#
# Episode:  185
# Min Score: 14.78  Max Score: 37.63
# AvgScore: 23.13
# Time: 40.69 seconds
#
# Episode:  186
# Min Score: 23.62  Max Score: 34.83
# AvgScore: 23.25
# Time: 43.96 seconds
#
# Episode:  187
# Min Score: 20.91  Max Score: 31.00
# AvgScore: 23.34
# Time: 41.26 seconds
#
# Episode:  188
# Min Score: 20.72  Max Score: 34.93
# AvgScore: 23.43
# Time: 41.37 seconds
#
# Episode:  189
# Min Score: 21.28  Max Score: 33.28
# AvgScore: 23.51
# Time: 41.23 seconds
#
# Episode:  190
# Min Score: 10.37  Max Score: 26.60
# AvgScore: 23.54
# Time: 41.55 seconds
#
# Episode:  191
# Min Score: 17.57  Max Score: 32.51
# AvgScore: 23.59
# Time: 41.93 seconds
#
# Episode:  192
# Min Score: 14.19  Max Score: 39.87
# AvgScore: 23.64
# Time: 41.96 seconds
#
# Episode:  193
# Min Score: 17.26  Max Score: 32.98
# AvgScore: 23.70
# Time: 42.07 seconds
#
# Episode:  194
# Min Score: 15.10  Max Score: 32.12
# AvgScore: 23.73
# Time: 43.75 seconds
#
# Episode:  195
# Min Score: 13.65  Max Score: 34.58
# AvgScore: 23.76
# Time: 42.75 seconds
#
# Episode:  196
# Min Score: 14.09  Max Score: 32.77
# AvgScore: 23.79
# Time: 42.81 seconds
#
# Episode:  197
# Min Score: 17.57  Max Score: 32.78
# AvgScore: 23.81
# Time: 43.96 seconds
#
# Episode:  198
# Min Score: 15.97  Max Score: 33.63
# AvgScore: 23.85
# Time: 41.75 seconds
#
# Episode:  199
# Min Score: 9.39  Max Score: 30.59
# AvgScore: 23.88
# Time: 43.67 seconds
#
# Episode:  200
# Min Score: 14.71  Max Score: 34.43
# AvgScore: 23.93
# Time: 44.82 seconds
#
# Episode:  201
# Min Score: 13.70  Max Score: 34.02
# AvgScore: 23.94
# Time: 46.12 seconds
#
# Episode:  202
# Min Score: 14.39  Max Score: 27.37
# AvgScore: 23.94
# Time: 42.38 seconds
#
# Episode:  203
# Min Score: 13.41  Max Score: 32.58
# AvgScore: 23.95
# Time: 41.06 seconds
#
# Episode:  204
# Min Score: 13.77  Max Score: 32.83
# AvgScore: 23.96
# Time: 42.03 seconds
#
# Episode:  205
# Min Score: 11.55  Max Score: 29.58
# AvgScore: 23.94
# Time: 41.69 seconds
#
# Episode:  206
# Min Score: 13.26  Max Score: 32.18
# AvgScore: 23.99
# Time: 43.13 seconds
#
# Episode:  207
# Min Score: 16.05  Max Score: 27.47
# AvgScore: 24.00
# Time: 44.88 seconds
#
# Episode:  208
# Min Score: 13.01  Max Score: 34.36
# AvgScore: 24.05
# Time: 42.79 seconds
#
# Episode:  209
# Min Score: 11.79  Max Score: 28.96
# AvgScore: 24.04
# Time: 41.36 seconds
#
# Episode:  210
# Min Score: 13.16  Max Score: 29.20
# AvgScore: 24.06
# Time: 42.83 seconds
#
# Episode:  211
# Min Score: 13.42  Max Score: 30.50
# AvgScore: 24.08
# Time: 41.60 seconds
#
# Episode:  212
# Min Score: 18.39  Max Score: 37.67
# AvgScore: 24.10
# Time: 41.78 seconds
#
# Episode:  213
# Min Score: 8.78  Max Score: 32.66
# AvgScore: 24.08
# Time: 42.52 seconds
#
# Episode:  214
# Min Score: 16.16  Max Score: 29.19
# AvgScore: 24.11
# Time: 41.38 seconds
#
# Episode:  215
# Min Score: 17.23  Max Score: 33.53
# AvgScore: 24.11
# Time: 41.69 seconds
#
# Episode:  216
# Min Score: 18.01  Max Score: 34.90
# AvgScore: 24.16
# Time: 41.73 seconds
#
# Episode:  217
# Min Score: 16.90  Max Score: 28.48
# AvgScore: 24.12
# Time: 40.85 seconds
#
# Episode:  218
# Min Score: 16.80  Max Score: 29.37
# AvgScore: 24.14
# Time: 42.36 seconds
#
# Episode:  219
# Min Score: 17.10  Max Score: 34.84
# AvgScore: 24.15
# Time: 42.82 seconds
#
# Episode:  220
# Min Score: 16.57  Max Score: 25.85
# AvgScore: 24.13
# Time: 41.65 seconds
#
# Episode:  221
# Min Score: 16.04  Max Score: 33.72
# AvgScore: 24.16
# Time: 41.47 seconds
#
# Episode:  222
# Min Score: 19.16  Max Score: 39.40
# AvgScore: 24.18
# Time: 41.98 seconds
#
# Episode:  223
# Min Score: 18.86  Max Score: 30.01
# AvgScore: 24.16
# Time: 42.00 seconds
#
# Episode:  224
# Min Score: 19.16  Max Score: 26.78
# AvgScore: 24.20
# Time: 41.10 seconds
#
# Episode:  225
# Min Score: 19.29  Max Score: 30.15
# AvgScore: 24.23
# Time: 45.15 seconds
#
# Episode:  226
# Min Score: 18.60  Max Score: 38.01
# AvgScore: 24.22
# Time: 42.88 seconds
#
# Episode:  227
# Min Score: 19.82  Max Score: 32.24
# AvgScore: 24.26
# Time: 40.20 seconds
#
# Episode:  228
# Min Score: 20.76  Max Score: 33.33
# AvgScore: 24.30
# Time: 41.55 seconds
#
# Episode:  229
# Min Score: 20.07  Max Score: 39.07
# AvgScore: 24.34
# Time: 41.18 seconds
#
# Episode:  230
# Min Score: 19.30  Max Score: 35.90
# AvgScore: 24.36
# Time: 41.05 seconds
#
# Episode:  231
# Min Score: 20.28  Max Score: 38.13
# AvgScore: 24.41
# Time: 41.92 seconds
#
# Episode:  232
# Min Score: 18.58  Max Score: 37.40
# AvgScore: 24.45
# Time: 40.83 seconds
#
# Episode:  233
# Min Score: 16.50  Max Score: 35.64
# AvgScore: 24.45
# Time: 41.46 seconds
#
# Episode:  234
# Min Score: 19.60  Max Score: 35.47
# AvgScore: 24.46
# Time: 41.56 seconds
#
# Episode:  235
# Min Score: 19.33  Max Score: 38.57
# AvgScore: 24.48
# Time: 41.03 seconds
#
# Episode:  236
# Min Score: 20.82  Max Score: 35.69
# AvgScore: 24.47
# Time: 45.31 seconds
#
# Episode:  237
# Min Score: 17.54  Max Score: 31.30
# AvgScore: 24.46
# Time: 46.81 seconds
#
# Episode:  238
# Min Score: 25.84  Max Score: 36.50
# AvgScore: 24.54
# Time: 44.42 seconds
#
# Episode:  239
# Min Score: 23.34  Max Score: 36.23
# AvgScore: 24.57
# Time: 43.63 seconds
#
# Episode:  240
# Min Score: 22.02  Max Score: 33.74
# AvgScore: 24.63
# Time: 43.61 seconds
#
# Episode:  241
# Min Score: 21.86  Max Score: 38.23
# AvgScore: 24.71
# Time: 44.25 seconds
#
# Episode:  242
# Min Score: 22.78  Max Score: 36.53
# AvgScore: 24.75
# Time: 42.23 seconds
#
# Episode:  243
# Min Score: 20.93  Max Score: 35.91
# AvgScore: 24.78
# Time: 45.21 seconds
#
# Episode:  244
# Min Score: 19.08  Max Score: 37.68
# AvgScore: 24.85
# Time: 41.80 seconds
#
# Episode:  245
# Min Score: 20.14  Max Score: 31.67
# AvgScore: 24.92
# Time: 42.05 seconds
#
# Episode:  246
# Min Score: 15.35  Max Score: 35.91
# AvgScore: 24.98
# Time: 41.61 seconds
#
# Episode:  247
# Min Score: 18.84  Max Score: 36.45
# AvgScore: 25.03
# Time: 41.45 seconds
#
# Episode:  248
# Min Score: 18.95  Max Score: 33.74
# AvgScore: 25.09
# Time: 43.52 seconds
#
# Episode:  249
# Min Score: 17.61  Max Score: 32.14
# AvgScore: 25.14
# Time: 41.53 seconds
#
# Episode:  250
# Min Score: 18.66  Max Score: 32.87
# AvgScore: 25.22
# Time: 41.34 seconds
#
# Episode:  251
# Min Score: 21.87  Max Score: 36.16
# AvgScore: 25.30
# Time: 42.23 seconds
#
# Episode:  252
# Min Score: 19.50  Max Score: 40.77
# AvgScore: 25.37
# Time: 41.85 seconds
#
# Episode:  253
# Min Score: 19.24  Max Score: 30.77
# AvgScore: 25.39
# Time: 41.97 seconds
#
# Episode:  254
# Min Score: 24.44  Max Score: 35.41
# AvgScore: 25.46
# Time: 42.02 seconds
#
# Episode:  255
# Min Score: 21.50  Max Score: 41.70
# AvgScore: 25.49
# Time: 40.79 seconds
#
# Episode:  256
# Min Score: 24.02  Max Score: 32.74
# AvgScore: 25.49
# Time: 42.55 seconds
#
# Episode:  257
# Min Score: 19.39  Max Score: 37.91
# AvgScore: 25.50
# Time: 41.60 seconds
#
# Episode:  258
# Min Score: 22.89  Max Score: 34.79
# AvgScore: 25.53
# Time: 44.05 seconds
#
# Episode:  259
# Min Score: 21.27  Max Score: 29.23
# AvgScore: 25.55
# Time: 46.01 seconds
#
# Episode:  260
# Min Score: 22.70  Max Score: 32.73
# AvgScore: 25.57
# Time: 47.94 seconds
#
# Episode:  261
# Min Score: 22.12  Max Score: 32.42
# AvgScore: 25.62
# Time: 45.50 seconds
#
# Episode:  262
# Min Score: 14.80  Max Score: 30.39
# AvgScore: 25.66
# Time: 44.95 seconds
#
# Episode:  263
# Min Score: 21.24  Max Score: 38.87
# AvgScore: 25.69
# Time: 42.87 seconds
#
# Episode:  264
# Min Score: 20.07  Max Score: 31.23
# AvgScore: 25.66
# Time: 45.13 seconds
#
# Episode:  265
# Min Score: 17.66  Max Score: 38.36
# AvgScore: 25.68
# Time: 43.04 seconds
#
# Episode:  266
# Min Score: 20.43  Max Score: 37.86
# AvgScore: 25.69
# Time: 42.27 seconds
#
# Episode:  267
# Min Score: 19.90  Max Score: 32.96
# AvgScore: 25.72
# Time: 46.08 seconds
#
# Episode:  268
# Min Score: 15.52  Max Score: 31.00
# AvgScore: 25.69
# Time: 49.80 seconds
#
# Episode:  269
# Min Score: 19.82  Max Score: 36.12
# AvgScore: 25.67
# Time: 49.77 seconds
#
# Episode:  270
# Min Score: 16.93  Max Score: 33.33
# AvgScore: 25.63
# Time: 44.52 seconds
#
# Episode:  271
# Min Score: 15.98  Max Score: 40.07
# AvgScore: 25.61
# Time: 42.00 seconds
#
# Episode:  272
# Min Score: 22.61  Max Score: 33.53
# AvgScore: 25.61
# Time: 41.78 seconds
#
# Episode:  273
# Min Score: 16.91  Max Score: 33.78
# AvgScore: 25.59
# Time: 43.94 seconds
#
# Episode:  274
# Min Score: 17.13  Max Score: 34.36
# AvgScore: 25.54
# Time: 41.60 seconds
#
# Episode:  275
# Min Score: 23.18  Max Score: 38.44
# AvgScore: 25.57
# Time: 44.54 seconds
#
# Episode:  276
# Min Score: 19.63  Max Score: 37.08
# AvgScore: 25.57
# Time: 43.83 seconds
#
# Episode:  277
# Min Score: 24.74  Max Score: 34.69
# AvgScore: 25.60
# Time: 42.90 seconds
#
# Episode:  278
# Min Score: 23.09  Max Score: 31.70
# AvgScore: 25.58
# Time: 44.22 seconds
#
# Episode:  279
# Min Score: 22.21  Max Score: 34.18
# AvgScore: 25.56
# Time: 42.68 seconds
#
# Episode:  280
# Min Score: 21.24  Max Score: 36.09
# AvgScore: 25.57
# Time: 42.94 seconds
#
# Episode:  281
# Min Score: 21.79  Max Score: 32.71
# AvgScore: 25.53
# Time: 45.16 seconds
#
# Episode:  282
# Min Score: 18.92  Max Score: 31.56
# AvgScore: 25.52
# Time: 42.71 seconds
#
# Episode:  283
# Min Score: 20.18  Max Score: 31.93
# AvgScore: 25.49
# Time: 43.24 seconds
#
# Episode:  284
# Min Score: 18.79  Max Score: 39.26
# AvgScore: 25.51
# Time: 43.57 seconds
#
# Episode:  285
# Min Score: 22.40  Max Score: 33.78
# AvgScore: 25.50
# Time: 44.26 seconds
#
# Episode:  286
# Min Score: 13.54  Max Score: 29.62
# AvgScore: 25.45
# Time: 44.88 seconds
#
# Episode:  287
# Min Score: 18.20  Max Score: 34.04
# AvgScore: 25.42
# Time: 43.70 seconds
#
# Episode:  288
# Min Score: 14.89  Max Score: 33.46
# AvgScore: 25.41
# Time: 44.83 seconds
#
# Episode:  289
# Min Score: 15.91  Max Score: 32.16
# AvgScore: 25.40
# Time: 44.99 seconds
#
# Episode:  290
# Min Score: 14.66  Max Score: 31.51
# AvgScore: 25.43
# Time: 42.28 seconds
#
# Episode:  291
# Min Score: 21.59  Max Score: 32.90
# AvgScore: 25.48
# Time: 42.25 seconds
#
# Episode:  292
# Min Score: 19.61  Max Score: 32.45
# AvgScore: 25.51
# Time: 42.05 seconds
#
# Episode:  293
# Min Score: 18.23  Max Score: 33.95
# AvgScore: 25.54
# Time: 42.85 seconds
#
# Episode:  294
# Min Score: 19.31  Max Score: 37.31
# AvgScore: 25.58
# Time: 41.28 seconds
#
# Episode:  295
# Min Score: 17.21  Max Score: 33.45
# AvgScore: 25.65
# Time: 42.85 seconds
#
# Episode:  296
# Min Score: 19.72  Max Score: 37.15
# AvgScore: 25.71
# Time: 42.50 seconds
#
# Episode:  297
# Min Score: 19.81  Max Score: 35.21
# AvgScore: 25.77
# Time: 43.05 seconds
#
# Episode:  298
# Min Score: 23.19  Max Score: 36.43
# AvgScore: 25.86
# Time: 44.03 seconds
#
# Episode:  299
# Min Score: 26.80  Max Score: 39.73
# AvgScore: 25.99
# Time: 42.16 seconds
#
# Episode:  300
# Min Score: 28.37  Max Score: 37.73
# AvgScore: 26.08
# Time: 43.11 seconds
#
# Episode:  301
# Min Score: 26.18  Max Score: 43.52
# AvgScore: 26.19
# Time: 42.57 seconds
#
# Episode:  302
# Min Score: 27.37  Max Score: 37.90
# AvgScore: 26.30
# Time: 43.61 seconds
#
# Episode:  303
# Min Score: 27.25  Max Score: 40.71
# AvgScore: 26.44
# Time: 45.04 seconds
#
# Episode:  304
# Min Score: 26.80  Max Score: 38.11
# AvgScore: 26.53
# Time: 43.36 seconds
#
# Episode:  305
# Min Score: 26.01  Max Score: 37.79
# AvgScore: 26.64
# Time: 43.77 seconds
#
# Episode:  306
# Min Score: 24.70  Max Score: 38.54
# AvgScore: 26.72
# Time: 45.13 seconds
#
# Episode:  307
# Min Score: 25.32  Max Score: 41.36
# AvgScore: 26.85
# Time: 43.17 seconds
#
# Episode:  308
# Min Score: 27.65  Max Score: 41.65
# AvgScore: 26.95
# Time: 43.69 seconds
#
# Episode:  309
# Min Score: 27.85  Max Score: 41.32
# AvgScore: 27.07
# Time: 42.57 seconds
#
# Episode:  310
# Min Score: 26.31  Max Score: 39.87
# AvgScore: 27.19
# Time: 42.69 seconds
#
# Episode:  311
# Min Score: 27.44  Max Score: 43.41
# AvgScore: 27.32
# Time: 43.63 seconds
#
# Episode:  312
# Min Score: 25.50  Max Score: 40.07
# AvgScore: 27.41
# Time: 42.85 seconds
#
# Episode:  313
# Min Score: 25.60  Max Score: 37.89
# AvgScore: 27.53
# Time: 43.45 seconds
#
# Episode:  314
# Min Score: 29.84  Max Score: 41.35
# AvgScore: 27.65
# Time: 43.37 seconds
#
# Episode:  315
# Min Score: 31.58  Max Score: 40.78
# AvgScore: 27.79
# Time: 46.09 seconds
#
# Episode:  316
# Min Score: 25.35  Max Score: 37.48
# AvgScore: 27.89
# Time: 44.00 seconds
#
# Episode:  317
# Min Score: 26.58  Max Score: 42.74
# AvgScore: 28.02
# Time: 46.27 seconds
#
# Episode:  318
# Min Score: 28.97  Max Score: 39.38
# AvgScore: 28.13
# Time: 43.70 seconds
#
# Episode:  319
# Min Score: 28.61  Max Score: 41.64
# AvgScore: 28.24
# Time: 42.87 seconds
#
# Episode:  320
# Min Score: 31.64  Max Score: 42.91
# AvgScore: 28.38
# Time: 44.45 seconds
#
# Episode:  321
# Min Score: 24.08  Max Score: 42.71
# AvgScore: 28.47
# Time: 44.38 seconds
#
# Episode:  322
# Min Score: 24.49  Max Score: 38.74
# AvgScore: 28.55
# Time: 42.91 seconds
#
# Episode:  323
# Min Score: 28.03  Max Score: 38.68
# AvgScore: 28.64
# Time: 43.02 seconds
#
# Episode:  324
# Min Score: 26.97  Max Score: 43.99
# AvgScore: 28.73
# Time: 42.95 seconds
#
# Episode:  325
# Min Score: 23.57  Max Score: 44.51
# AvgScore: 28.81
# Time: 42.46 seconds
#
# Episode:  326
# Min Score: 24.50  Max Score: 36.82
# AvgScore: 28.90
# Time: 43.99 seconds
#
# Episode:  327
# Min Score: 28.80  Max Score: 39.93
# AvgScore: 28.99
# Time: 42.30 seconds
#
# Episode:  328
# Min Score: 25.88  Max Score: 37.44
# AvgScore: 29.06
# Time: 43.08 seconds
#
# Episode:  329
# Min Score: 24.96  Max Score: 40.72
# AvgScore: 29.09
# Time: 42.64 seconds
#
# Episode:  330
# Min Score: 26.22  Max Score: 39.83
# AvgScore: 29.16
# Time: 42.12 seconds
#
# Episode:  331
# Min Score: 25.96  Max Score: 41.37
# AvgScore: 29.20
# Time: 42.89 seconds
#
# Episode:  332
# Min Score: 27.79  Max Score: 42.42
# AvgScore: 29.27
# Time: 42.08 seconds
#
# Episode:  333
# Min Score: 26.83  Max Score: 40.56
# AvgScore: 29.34
# Time: 44.90 seconds
#
# Episode:  334
# Min Score: 26.85  Max Score: 39.76
# AvgScore: 29.41
# Time: 44.11 seconds
#
# Episode:  335
# Min Score: 24.38  Max Score: 38.85
# AvgScore: 29.46
# Time: 45.11 seconds
#
# Episode:  336
# Min Score: 24.47  Max Score: 39.48
# AvgScore: 29.49
# Time: 46.53 seconds
#
# Episode:  337
# Min Score: 23.10  Max Score: 40.24
# AvgScore: 29.58
# Time: 42.98 seconds
#
# Episode:  338
# Min Score: 28.59  Max Score: 38.41
# AvgScore: 29.62
# Time: 43.65 seconds
#
# Episode:  339
# Min Score: 29.31  Max Score: 40.66
# AvgScore: 29.67
# Time: 46.42 seconds
#
# Episode:  340
# Min Score: 23.05  Max Score: 38.43
# AvgScore: 29.73
# Time: 44.06 seconds
#
# Episode:  341
# Min Score: 22.08  Max Score: 38.56
# AvgScore: 29.77
# Time: 42.82 seconds
#
# Episode:  342
# Min Score: 22.27  Max Score: 44.08
# AvgScore: 29.83
# Time: 44.34 seconds
#
# Episode:  343
# Min Score: 25.74  Max Score: 39.81
# AvgScore: 29.90
# Time: 43.07 seconds
#
# Episode:  344
# Min Score: 22.13  Max Score: 39.37
# AvgScore: 29.95
# Time: 45.03 seconds
#
# Episode:  345
# Min Score: 25.90  Max Score: 43.98
# AvgScore: 30.03
# Time: 43.46 seconds

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')

plt.show()
